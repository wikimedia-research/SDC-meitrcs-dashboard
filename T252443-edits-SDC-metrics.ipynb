# %% [markdown]
# # SDC/Non-SDC Edits to Files on Commons

# %% [markdown]
# [T252443](https://phabricator.wikimedia.org/T252443)

# %% [markdown]
# This set of metrics is aiming to understand to what extent SDC has led to users updating structured data about existing media. It might be that users are instead adding structured data when uploading new media.

# %%
import datetime as dt
import pandas as pd
import numpy as np

from wmfdata import hive, spark
# Out:
# You are using wmfdata v1.3.1, but v1.3.3 is available.
#
# To update, run `pip install --upgrade git+https://github.com/wikimedia/wmfdata-python.git@release --ignore-installed`.
#
# To see the changes, refer to https://github.com/wikimedia/wmfdata-python/blob/release/CHANGELOG.md

# %% [markdown]
# ### Configuration variables

# %%
wmf_snapshot = '2022-02'
start_date = '2022-02-01'
end_date = '2022-03-01'

# %% [markdown]
# ### Approach

# %% [markdown]
# We'll use edit comments to identify structured data edits, and then use timestamps to measure time to edit since the page was created. Then, we'll plot a histogram to see if there's a reasonable cutoff we can use for separating edits happening around the initial upload from those happening later.
#
# For non-SDC edits, we'll look for edits that added information to a page. These edits cannot be a revert, because that would mean it's reinstating a previous state of the file, nor should it have been reverted within 48 hours, as that would mean it's likely an unproductive edit.
#
# In both cases, we'll only look at non-bot edits to files (page_namespace = 6) that have not been deleted. While there might also have been valid edits to deleted files, we are mainly interested in learning whether existing pages are updated with structured data.

# %% [markdown]
# ### Aggregation Tables

# %% [markdown]
# We define a set of tables in the Data Lake for aggregation of results.

# %%
edit_table = 'cchen_sd.sdc_edits_count'

# %%
create_table_query = '''
CREATE TABLE IF NOT EXISTS {table_name} (
    month DATE COMMENT "the month of the aggregated caption time counts",
    edit_type STRING COMMENT "SDC or non-SDC edits",
    time_to_edits STRING COMMENT "bucketed time to edits for data ",
    max_time_to_edits BIGINT COMMENT "max time within each bucket (for Superset chart)",
    edit_count BIGINT COMMENT "Aggregated number of edits"
)
'''

# %%
hive.run(create_table_query.format(
            table_name = edit_table
))

# %% [markdown]
# ### Edit data

# %%
edits_query = '''
WITH edits_data (
    SELECT 
        unix_timestamp(event_timestamp) - unix_timestamp(page_creation_timestamp) AS time_to_edit,
        CASE WHEN (event_comment REGEXP "^...wbsetclaim-create:.*?Special:EntityPage/(P\\\\d+)"
                OR event_comment REGEXP "^...wbsetlabel-add:"
                OR event_comment REGEXP "^...wbcreateclaim-create:"
                OR event_comment REGEXP "^...wbeditentity-update:") THEN "sdc"
             WHEN (event_comment NOT REGEXP "^...wbsetclaim-create:.*?Special:EntityPage/(P\\\\d+)"
                AND event_comment NOT REGEXP "^...wbsetlabel-add:"
                AND event_comment NOT REGEXP "^...wbcreateclaim-create:"
                AND event_comment NOT REGEXP "^...wbeditentity-update:"
                AND revision_text_bytes_diff > 0
                AND (revision_is_identity_reverted = false
                    OR revision_seconds_to_identity_revert > 48 * 60 * 60)
                AND revision_is_identity_revert = false) THEN "non-sdc"
        END AS edit_type
    FROM wmf.mediawiki_history
    WHERE snapshot = "{snapshot}"
      AND wiki_db = "commonswiki"
      AND event_entity = "revision"
      AND event_type = "create"
      AND event_timestamp >= "{start_date}"
      AND event_timestamp < "{end_date}"
      AND page_namespace = 6 -- only files
      AND page_is_deleted = false -- only live pages
      AND size(event_user_is_bot_by_historical) = 0 -- no bots
      AND size(event_user_is_bot_by) = 0 -- no bots
),

bucketed_edits_data AS (
    SELECT 
        time_to_edit,
        CASE WHEN time_to_edit < 60 THEN '0-1min'
             WHEN time_to_edit >= 60 and time_to_edit < 60*60 THEN '1-60min'
             WHEN time_to_edit >= 60*60 and time_to_edit < 60*60*12 THEN '1-12h'
             WHEN time_to_edit >= 60*60*12 and time_to_edit < 60*60*24 THEN '12-24h'
             WHEN time_to_edit >= 60*60*24 and time_to_edit < 7*24*60*60 THEN '1d-1w'
             WHEN time_to_edit >= 60*60*24*7 and time_to_edit < 30*24*60*60 THEN '1w-1m'
             WHEN time_to_edit >= 30*24*60*60 and time_to_edit < 90*24*60*60 THEN '1m-3m'
             WHEN time_to_edit >= 90*24*60*60 and time_to_edit < 180*24*60*60 THEN '3m-6m'
             WHEN time_to_edit >= 180*24*60*60 and time_to_edit < 365*24*60*60 THEN '6m-1y'
             WHEN time_to_edit >= 60*60*24*365 and time_to_edit < 365*24*60*60*5 THEN '1y-5y'
             WHEN time_to_edit >= 365*24*60*60*5 and time_to_edit < 365*24*60*60*10 THEN '5y-10y'
             WHEN time_to_edit >= 365*24*60*60*10 THEN '10y+'
        END AS edits_time,
        edit_type
    FROM edits_data
    WHERE edit_type IS NOT NULL
)

INSERT INTO {aggregate_table}
SELECT
    "{start_date}" AS month,
    edit_type,
    edits_time AS time_to_edits,
    MAX(time_to_edit) AS max_time_to_edits,
    COUNT(*) AS edit_count
FROM bucketed_edits_data
GROUP BY edit_type, edits_time
'''

# %%
spark.run(edits_query.format(
   snapshot = wmf_snapshot,
    start_date = start_date,
    end_date = end_date,   
    aggregate_table = edit_table
))
# Out:
# PySpark executors will use /usr/lib/anaconda-wmf/bin/python3.
# [Stage 3:=========>                                         (1150 + 154) / 6144]22/03/29 16:58:29 ERROR YarnScheduler: Lost executor 167 on an-worker1106.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:29 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 167 for reason Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:29 WARN TaskSetManager: Lost task 3326.0 in stage 3.0 (TID 7778, an-worker1106.eqiad.wmnet, executor 167): ExecutorLostFailure (executor 167 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:29 WARN TaskSetManager: Lost task 3609.0 in stage 3.0 (TID 7819, an-worker1106.eqiad.wmnet, executor 167): ExecutorLostFailure (executor 167 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:29 WARN TaskSetManager: Lost task 3289.0 in stage 3.0 (TID 7774, an-worker1106.eqiad.wmnet, executor 167): ExecutorLostFailure (executor 167 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:29 WARN TaskSetManager: Lost task 3185.0 in stage 3.0 (TID 7756, an-worker1106.eqiad.wmnet, executor 167): ExecutorLostFailure (executor 167 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:==========>                                        (1243 + 114) / 6144]22/03/29 16:58:32 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 155 for reason Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:32 ERROR YarnScheduler: Lost executor 155 on an-worker1124.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:32 WARN TaskSetManager: Lost task 5474.0 in stage 3.0 (TID 7816, an-worker1124.eqiad.wmnet, executor 155): ExecutorLostFailure (executor 155 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:32 WARN TaskSetManager: Lost task 5386.0 in stage 3.0 (TID 7809, an-worker1124.eqiad.wmnet, executor 155): ExecutorLostFailure (executor 155 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:32 WARN TaskSetManager: Lost task 5464.0 in stage 3.0 (TID 7814, an-worker1124.eqiad.wmnet, executor 155): ExecutorLostFailure (executor 155 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:==========>                                        (1248 + 109) / 6144]22/03/29 16:58:32 WARN TransportChannelHandler: Exception in connection from /10.64.21.7:35520
# java.io.IOException: Connection reset by peer
# 	at sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:223)
# 	at sun.nio.ch.IOUtil.read(IOUtil.java:192)
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:379)
# 	at io.netty.buffer.PooledUnsafeDirectByteBuf.setBytes(PooledUnsafeDirectByteBuf.java:288)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1106)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:343)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:123)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:645)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:580)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:497)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:459)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$5.run(SingleThreadEventExecutor.java:858)
# 	at io.netty.util.concurrent.DefaultThreadFactory$DefaultRunnableDecorator.run(DefaultThreadFactory.java:138)
# 	at java.lang.Thread.run(Thread.java:750)
# [Stage 3:==========>                                         (1295 + 94) / 6144]22/03/29 16:58:35 ERROR YarnScheduler: Lost executor 120 on an-worker1116.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:35 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 120 for reason Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:35 WARN TaskSetManager: Lost task 3962.0 in stage 3.0 (TID 7933, an-worker1116.eqiad.wmnet, executor 120): ExecutorLostFailure (executor 120 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:35 WARN TaskSetManager: Lost task 3859.0 in stage 3.0 (TID 7903, an-worker1116.eqiad.wmnet, executor 120): ExecutorLostFailure (executor 120 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:35 WARN TaskSetManager: Lost task 4120.0 in stage 3.0 (TID 7982, an-worker1116.eqiad.wmnet, executor 120): ExecutorLostFailure (executor 120 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:35 WARN TaskSetManager: Lost task 3961.0 in stage 3.0 (TID 7931, an-worker1116.eqiad.wmnet, executor 120): ExecutorLostFailure (executor 120 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:===========>                                        (1318 + 80) / 6144]22/03/29 16:58:36 ERROR YarnScheduler: Lost executor 139 on an-worker1124.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:36 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 139 for reason Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:36 WARN TaskSetManager: Lost task 5474.1 in stage 3.0 (TID 7958, an-worker1124.eqiad.wmnet, executor 139): ExecutorLostFailure (executor 139 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:===========>                                        (1372 + 56) / 6144]22/03/29 16:58:38 ERROR YarnScheduler: Lost executor 121 on an-worker1116.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:38 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 121 for reason Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:38 WARN TaskSetManager: Lost task 4228.0 in stage 3.0 (TID 8011, an-worker1116.eqiad.wmnet, executor 121): ExecutorLostFailure (executor 121 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:38 WARN TaskSetManager: Lost task 3961.1 in stage 3.0 (TID 7993, an-worker1116.eqiad.wmnet, executor 121): ExecutorLostFailure (executor 121 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:38 WARN TaskSetManager: Lost task 4152.0 in stage 3.0 (TID 8003, an-worker1116.eqiad.wmnet, executor 121): ExecutorLostFailure (executor 121 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:38 WARN TaskSetManager: Lost task 4125.0 in stage 3.0 (TID 7988, an-worker1116.eqiad.wmnet, executor 121): ExecutorLostFailure (executor 121 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:===========>                                        (1409 + 56) / 6144]22/03/29 16:58:41 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 118 for reason Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:41 ERROR YarnScheduler: Lost executor 118 on an-worker1116.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:41 WARN TaskSetManager: Lost task 4369.0 in stage 3.0 (TID 8029, an-worker1116.eqiad.wmnet, executor 118): ExecutorLostFailure (executor 118 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:41 WARN TaskSetManager: Lost task 4388.0 in stage 3.0 (TID 8032, an-worker1116.eqiad.wmnet, executor 118): ExecutorLostFailure (executor 118 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:41 WARN TaskSetManager: Lost task 4349.0 in stage 3.0 (TID 8028, an-worker1116.eqiad.wmnet, executor 118): ExecutorLostFailure (executor 118 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:41 WARN TaskSetManager: Lost task 4328.0 in stage 3.0 (TID 8027, an-worker1116.eqiad.wmnet, executor 118): ExecutorLostFailure (executor 118 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:41 WARN TransportChannelHandler: Exception in connection from /10.64.53.46:55404
# java.io.IOException: Connection reset by peer
# 	at sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:223)
# 	at sun.nio.ch.IOUtil.read(IOUtil.java:192)
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:379)
# 	at io.netty.buffer.PooledUnsafeDirectByteBuf.setBytes(PooledUnsafeDirectByteBuf.java:288)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1106)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:343)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:123)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:645)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:580)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:497)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:459)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$5.run(SingleThreadEventExecutor.java:858)
# 	at io.netty.util.concurrent.DefaultThreadFactory$DefaultRunnableDecorator.run(DefaultThreadFactory.java:138)
# 	at java.lang.Thread.run(Thread.java:750)
# [Stage 3:============>                                       (1443 + 56) / 6144]22/03/29 16:58:45 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 163 for reason Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:45 ERROR YarnScheduler: Lost executor 163 on an-worker1106.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:45 WARN TaskSetManager: Lost task 5799.0 in stage 3.0 (TID 8104, an-worker1106.eqiad.wmnet, executor 163): ExecutorLostFailure (executor 163 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:45 WARN TaskSetManager: Lost task 5530.0 in stage 3.0 (TID 8068, an-worker1106.eqiad.wmnet, executor 163): ExecutorLostFailure (executor 163 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:45 WARN TaskSetManager: Lost task 5378.0 in stage 3.0 (TID 8057, an-worker1106.eqiad.wmnet, executor 163): ExecutorLostFailure (executor 163 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:45 WARN TaskSetManager: Lost task 5311.0 in stage 3.0 (TID 8051, an-worker1106.eqiad.wmnet, executor 163): ExecutorLostFailure (executor 163 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:============>                                       (1450 + 52) / 6144]22/03/29 16:58:45 WARN TransportChannelHandler: Exception in connection from /10.64.36.138:33662
# java.io.IOException: Connection reset by peer
# 	at sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:223)
# 	at sun.nio.ch.IOUtil.read(IOUtil.java:192)
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:379)
# 	at io.netty.buffer.PooledUnsafeDirectByteBuf.setBytes(PooledUnsafeDirectByteBuf.java:288)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1106)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:343)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:123)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:645)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:580)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:497)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:459)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$5.run(SingleThreadEventExecutor.java:858)
# 	at io.netty.util.concurrent.DefaultThreadFactory$DefaultRunnableDecorator.run(DefaultThreadFactory.java:138)
# 	at java.lang.Thread.run(Thread.java:750)
# [Stage 3:============>                                       (1465 + 56) / 6144]22/03/29 16:58:47 ERROR YarnScheduler: Lost executor 122 on an-worker1116.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 122 for reason Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 WARN TaskSetManager: Lost task 4599.0 in stage 3.0 (TID 8095, an-worker1116.eqiad.wmnet, executor 122): ExecutorLostFailure (executor 122 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 WARN TaskSetManager: Lost task 4369.1 in stage 3.0 (TID 8091, an-worker1116.eqiad.wmnet, executor 122): ExecutorLostFailure (executor 122 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 WARN TaskSetManager: Lost task 4681.0 in stage 3.0 (TID 8100, an-worker1116.eqiad.wmnet, executor 122): ExecutorLostFailure (executor 122 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 WARN TaskSetManager: Lost task 4388.1 in stage 3.0 (TID 8090, an-worker1116.eqiad.wmnet, executor 122): ExecutorLostFailure (executor 122 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.6 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:============>                                       (1467 + 50) / 6144]22/03/29 16:58:47 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 160 for reason Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 ERROR YarnScheduler: Lost executor 160 on an-worker1106.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 WARN TaskSetManager: Lost task 5997.0 in stage 3.0 (TID 8131, an-worker1106.eqiad.wmnet, executor 160): ExecutorLostFailure (executor 160 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 WARN TaskSetManager: Lost task 5795.0 in stage 3.0 (TID 8103, an-worker1106.eqiad.wmnet, executor 160): ExecutorLostFailure (executor 160 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 WARN TaskSetManager: Lost task 5530.1 in stage 3.0 (TID 8117, an-worker1106.eqiad.wmnet, executor 160): ExecutorLostFailure (executor 160 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:58:47 WARN TaskSetManager: Lost task 5693.0 in stage 3.0 (TID 8093, an-worker1106.eqiad.wmnet, executor 160): ExecutorLostFailure (executor 160 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:============>                                       (1476 + 47) / 6144]22/03/29 16:58:48 WARN TransportChannelHandler: Exception in connection from /10.64.36.138:33676
# java.io.IOException: Connection reset by peer
# 	at sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:223)
# 	at sun.nio.ch.IOUtil.read(IOUtil.java:192)
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:379)
# 	at io.netty.buffer.PooledUnsafeDirectByteBuf.setBytes(PooledUnsafeDirectByteBuf.java:288)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1106)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:343)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:123)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:645)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:580)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:497)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:459)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$5.run(SingleThreadEventExecutor.java:858)
# 	at io.netty.util.concurrent.DefaultThreadFactory$DefaultRunnableDecorator.run(DefaultThreadFactory.java:138)
# 	at java.lang.Thread.run(Thread.java:750)
# [Stage 3:==============>                                     (1686 + 40) / 6144]22/03/29 16:59:12 ERROR YarnScheduler: Lost executor 119 on an-worker1116.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.2 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:12 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 119 for reason Container killed by YARN for exceeding memory limits.  9.2 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:12 WARN TaskSetManager: Lost task 5773.0 in stage 3.0 (TID 8328, an-worker1116.eqiad.wmnet, executor 119): ExecutorLostFailure (executor 119 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.2 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:12 WARN TaskSetManager: Lost task 5735.0 in stage 3.0 (TID 8327, an-worker1116.eqiad.wmnet, executor 119): ExecutorLostFailure (executor 119 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.2 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:12 WARN TaskSetManager: Lost task 5819.0 in stage 3.0 (TID 8329, an-worker1116.eqiad.wmnet, executor 119): ExecutorLostFailure (executor 119 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.2 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:12 WARN TaskSetManager: Lost task 5873.0 in stage 3.0 (TID 8332, an-worker1116.eqiad.wmnet, executor 119): ExecutorLostFailure (executor 119 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.2 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:================>                                   (2005 + 33) / 6144]22/03/29 16:59:49 ERROR YarnScheduler: Lost executor 182 on an-worker1088.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:49 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 182 for reason Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:49 WARN TaskSetManager: Lost task 1296.0 in stage 3.0 (TID 8633, an-worker1088.eqiad.wmnet, executor 182): ExecutorLostFailure (executor 182 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:49 WARN TaskSetManager: Lost task 1182.0 in stage 3.0 (TID 8629, an-worker1088.eqiad.wmnet, executor 182): ExecutorLostFailure (executor 182 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:49 WARN TaskSetManager: Lost task 1315.0 in stage 3.0 (TID 8664, an-worker1088.eqiad.wmnet, executor 182): ExecutorLostFailure (executor 182 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 16:59:49 WARN TaskSetManager: Lost task 1195.0 in stage 3.0 (TID 8631, an-worker1088.eqiad.wmnet, executor 182): ExecutorLostFailure (executor 182 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:==================>                                 (2168 + 20) / 6144]22/03/29 17:00:16 ERROR YarnScheduler: Lost executor 180 on an-worker1122.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:16 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 180 for reason Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:16 WARN TaskSetManager: Lost task 1855.0 in stage 3.0 (TID 8813, an-worker1122.eqiad.wmnet, executor 180): ExecutorLostFailure (executor 180 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:16 WARN TaskSetManager: Lost task 1718.0 in stage 3.0 (TID 8804, an-worker1122.eqiad.wmnet, executor 180): ExecutorLostFailure (executor 180 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:16 WARN TaskSetManager: Lost task 1719.0 in stage 3.0 (TID 8806, an-worker1122.eqiad.wmnet, executor 180): ExecutorLostFailure (executor 180 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:16 WARN TaskSetManager: Lost task 1844.0 in stage 3.0 (TID 8809, an-worker1122.eqiad.wmnet, executor 180): ExecutorLostFailure (executor 180 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:==================>                                 (2174 + 16) / 6144]22/03/29 17:00:18 ERROR YarnScheduler: Lost executor 184 on an-worker1089.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.5 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 184 for reason Container killed by YARN for exceeding memory limits.  9.5 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 186 for reason Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN TaskSetManager: Lost task 4132.0 in stage 3.0 (TID 8824, an-worker1089.eqiad.wmnet, executor 184): ExecutorLostFailure (executor 184 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.5 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN TaskSetManager: Lost task 4037.0 in stage 3.0 (TID 8815, an-worker1089.eqiad.wmnet, executor 184): ExecutorLostFailure (executor 184 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.5 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN TaskSetManager: Lost task 4160.0 in stage 3.0 (TID 8825, an-worker1089.eqiad.wmnet, executor 184): ExecutorLostFailure (executor 184 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.5 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN TaskSetManager: Lost task 3977.0 in stage 3.0 (TID 8810, an-worker1089.eqiad.wmnet, executor 184): ExecutorLostFailure (executor 184 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.5 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 ERROR YarnScheduler: Lost executor 186 on an-worker1110.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN TaskSetManager: Lost task 3473.0 in stage 3.0 (TID 8818, an-worker1110.eqiad.wmnet, executor 186): ExecutorLostFailure (executor 186 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN TaskSetManager: Lost task 3446.0 in stage 3.0 (TID 8814, an-worker1110.eqiad.wmnet, executor 186): ExecutorLostFailure (executor 186 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN TaskSetManager: Lost task 3460.0 in stage 3.0 (TID 8816, an-worker1110.eqiad.wmnet, executor 186): ExecutorLostFailure (executor 186 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:18 WARN TaskSetManager: Lost task 3479.0 in stage 3.0 (TID 8819, an-worker1110.eqiad.wmnet, executor 186): ExecutorLostFailure (executor 186 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:==================>                                  (2174 + 8) / 6144]22/03/29 17:00:18 WARN TransportChannelHandler: Exception in connection from /10.64.36.142:41076
# java.io.IOException: Connection reset by peer
# 	at sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:223)
# 	at sun.nio.ch.IOUtil.read(IOUtil.java:192)
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:379)
# 	at io.netty.buffer.PooledUnsafeDirectByteBuf.setBytes(PooledUnsafeDirectByteBuf.java:288)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1106)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:343)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:123)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:645)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:580)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:497)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:459)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$5.run(SingleThreadEventExecutor.java:858)
# 	at io.netty.util.concurrent.DefaultThreadFactory$DefaultRunnableDecorator.run(DefaultThreadFactory.java:138)
# 	at java.lang.Thread.run(Thread.java:750)
# [Stage 3:==================>                                 (2189 + 20) / 6144]22/03/29 17:00:27 ERROR YarnScheduler: Lost executor 189 on an-worker1108.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:27 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 189 for reason Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:27 WARN TaskSetManager: Lost task 4013.0 in stage 3.0 (TID 8849, an-worker1108.eqiad.wmnet, executor 189): ExecutorLostFailure (executor 189 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:27 WARN TaskSetManager: Lost task 4284.0 in stage 3.0 (TID 8851, an-worker1108.eqiad.wmnet, executor 189): ExecutorLostFailure (executor 189 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:27 WARN TaskSetManager: Lost task 4351.0 in stage 3.0 (TID 8853, an-worker1108.eqiad.wmnet, executor 189): ExecutorLostFailure (executor 189 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:00:27 WARN TaskSetManager: Lost task 4192.0 in stage 3.0 (TID 8850, an-worker1108.eqiad.wmnet, executor 189): ExecutorLostFailure (executor 189 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.4 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:===================>                                (2353 + 16) / 6144]22/03/29 17:01:15 ERROR YarnScheduler: Lost executor 190 on an-worker1088.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:15 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 190 for reason Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:15 WARN TaskSetManager: Lost task 2767.0 in stage 3.0 (TID 9001, an-worker1088.eqiad.wmnet, executor 190): ExecutorLostFailure (executor 190 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:15 WARN TaskSetManager: Lost task 2829.0 in stage 3.0 (TID 9007, an-worker1088.eqiad.wmnet, executor 190): ExecutorLostFailure (executor 190 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:15 WARN TaskSetManager: Lost task 2849.0 in stage 3.0 (TID 9009, an-worker1088.eqiad.wmnet, executor 190): ExecutorLostFailure (executor 190 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:15 WARN TaskSetManager: Lost task 2809.0 in stage 3.0 (TID 9006, an-worker1088.eqiad.wmnet, executor 190): ExecutorLostFailure (executor 190 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:====================>                               (2368 + 12) / 6144]22/03/29 17:01:21 ERROR YarnScheduler: Lost executor 193 on an-worker1126.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:21 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 193 for reason Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:21 WARN TaskSetManager: Lost task 1737.0 in stage 3.0 (TID 9034, an-worker1126.eqiad.wmnet, executor 193): ExecutorLostFailure (executor 193 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:21 WARN TaskSetManager: Lost task 1651.0 in stage 3.0 (TID 9025, an-worker1126.eqiad.wmnet, executor 193): ExecutorLostFailure (executor 193 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:21 WARN TaskSetManager: Lost task 1664.0 in stage 3.0 (TID 9030, an-worker1126.eqiad.wmnet, executor 193): ExecutorLostFailure (executor 193 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:21 WARN TaskSetManager: Lost task 1660.0 in stage 3.0 (TID 9026, an-worker1126.eqiad.wmnet, executor 193): ExecutorLostFailure (executor 193 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:====================>                               (2444 + 12) / 6144]22/03/29 17:01:51 ERROR YarnScheduler: Lost executor 192 on an-worker1139.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:51 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 192 for reason Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:01:51 WARN TaskSetManager: Lost task 4519.0 in stage 3.0 (TID 9112, an-worker1139.eqiad.wmnet, executor 192): ExecutorLostFailure (executor 192 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# ...
# 22/03/29 17:12:56 WARN TaskSetManager: Lost task 3384.0 in stage 3.0 (TID 11771, an-worker1082.eqiad.wmnet, executor 208): ExecutorLostFailure (executor 208 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:==========================================>         (5079 + 12) / 6144]22/03/29 17:13:19 ERROR YarnScheduler: Lost executor 221 on an-worker1120.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:19 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 221 for reason Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:19 WARN TaskSetManager: Lost task 5275.0 in stage 3.0 (TID 11854, an-worker1120.eqiad.wmnet, executor 221): ExecutorLostFailure (executor 221 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:19 WARN TaskSetManager: Lost task 5273.0 in stage 3.0 (TID 11853, an-worker1120.eqiad.wmnet, executor 221): ExecutorLostFailure (executor 221 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:19 WARN TaskSetManager: Lost task 5202.0 in stage 3.0 (TID 11850, an-worker1120.eqiad.wmnet, executor 221): ExecutorLostFailure (executor 221 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:19 WARN TaskSetManager: Lost task 5285.0 in stage 3.0 (TID 11855, an-worker1120.eqiad.wmnet, executor 221): ExecutorLostFailure (executor 221 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.1 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:===========================================>        (5151 + 12) / 6144]22/03/29 17:13:46 ERROR YarnScheduler: Lost executor 226 on an-worker1132.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:46 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 226 for reason Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:46 WARN TaskSetManager: Lost task 1283.0 in stage 3.0 (TID 11931, an-worker1132.eqiad.wmnet, executor 226): ExecutorLostFailure (executor 226 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:46 WARN TaskSetManager: Lost task 1154.0 in stage 3.0 (TID 11930, an-worker1132.eqiad.wmnet, executor 226): ExecutorLostFailure (executor 226 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:46 WARN TaskSetManager: Lost task 1309.0 in stage 3.0 (TID 11933, an-worker1132.eqiad.wmnet, executor 226): ExecutorLostFailure (executor 226 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:13:46 WARN TaskSetManager: Lost task 1308.0 in stage 3.0 (TID 11932, an-worker1132.eqiad.wmnet, executor 226): ExecutorLostFailure (executor 226 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.0 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:==============================================>      (5333 + 4) / 6144]22/03/29 17:14:40 ERROR YarnScheduler: Lost executor 227 on an-worker1130.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:14:40 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 227 for reason Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:14:40 WARN TaskSetManager: Lost task 6031.0 in stage 3.0 (TID 12111, an-worker1130.eqiad.wmnet, executor 227): ExecutorLostFailure (executor 227 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:14:40 WARN TaskSetManager: Lost task 5777.0 in stage 3.0 (TID 12108, an-worker1130.eqiad.wmnet, executor 227): ExecutorLostFailure (executor 227 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:14:40 WARN TaskSetManager: Lost task 5848.0 in stage 3.0 (TID 12110, an-worker1130.eqiad.wmnet, executor 227): ExecutorLostFailure (executor 227 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:14:40 WARN TaskSetManager: Lost task 5796.0 in stage 3.0 (TID 12109, an-worker1130.eqiad.wmnet, executor 227): ExecutorLostFailure (executor 227 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  9.3 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:=============================================>     (5455 + 256) / 6144]22/03/29 17:15:01 ERROR YarnScheduler: Lost executor 152 on an-worker1124.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:01 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 152 for reason Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:01 WARN TaskSetManager: Lost task 3069.0 in stage 3.0 (TID 12407, an-worker1124.eqiad.wmnet, executor 152): ExecutorLostFailure (executor 152 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:01 WARN TaskSetManager: Lost task 1517.0 in stage 3.0 (TID 12281, an-worker1124.eqiad.wmnet, executor 152): ExecutorLostFailure (executor 152 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:01 WARN TaskSetManager: Lost task 589.0 in stage 3.0 (TID 12217, an-worker1124.eqiad.wmnet, executor 152): ExecutorLostFailure (executor 152 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:01 WARN TaskSetManager: Lost task 2476.0 in stage 3.0 (TID 12345, an-worker1124.eqiad.wmnet, executor 152): ExecutorLostFailure (executor 152 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.9 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:==============================================>    (5642 + 252) / 6144]22/03/29 17:15:05 ERROR YarnScheduler: Lost executor 144 on an-worker1083.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:05 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 144 for reason Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:05 WARN TaskSetManager: Lost task 4554.0 in stage 3.0 (TID 12611, an-worker1083.eqiad.wmnet, executor 144): ExecutorLostFailure (executor 144 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:05 WARN TaskSetManager: Lost task 67.0 in stage 3.0 (TID 12182, an-worker1083.eqiad.wmnet, executor 144): ExecutorLostFailure (executor 144 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:05 WARN TaskSetManager: Lost task 4410.0 in stage 3.0 (TID 12585, an-worker1083.eqiad.wmnet, executor 144): ExecutorLostFailure (executor 144 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:05 WARN TaskSetManager: Lost task 4420.0 in stage 3.0 (TID 12587, an-worker1083.eqiad.wmnet, executor 144): ExecutorLostFailure (executor 144 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:===================================================>(6106 + 38) / 6144]22/03/29 17:15:16 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 217 for reason Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:16 ERROR YarnScheduler: Lost executor 217 on analytics1072.eqiad.wmnet: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# 22/03/29 17:15:16 WARN TaskSetManager: Lost task 6103.0 in stage 3.0 (TID 12915, analytics1072.eqiad.wmnet, executor 217): ExecutorLostFailure (executor 217 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  8.8 GB of 8.8 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# [Stage 3:===================================================>(6132 + 12) / 6144]22/03/29 17:15:16 WARN TransportChannelHandler: Exception in connection from /10.64.21.116:42242
# java.io.IOException: Connection reset by peer
# 	at sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:223)
# 	at sun.nio.ch.IOUtil.read(IOUtil.java:192)
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:379)
# 	at io.netty.buffer.PooledUnsafeDirectByteBuf.setBytes(PooledUnsafeDirectByteBuf.java:288)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1106)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:343)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:123)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:645)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:580)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:497)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:459)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$5.run(SingleThreadEventExecutor.java:858)
# 	at io.netty.util.concurrent.DefaultThreadFactory$DefaultRunnableDecorator.run(DefaultThreadFactory.java:138)
# 	at java.lang.Thread.run(Thread.java:750)
# Exception in thread Thread-10:
# Traceback (most recent call last):
#   File "/home/conniecc1/.conda/envs/2021-04-28T21.02.04_conniecc1/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/conniecc1/.conda/envs/2021-04-28T21.02.04_conniecc1/lib/python3.7/threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
# TypeError: stop_session() missing 1 required positional argument: 'session'
